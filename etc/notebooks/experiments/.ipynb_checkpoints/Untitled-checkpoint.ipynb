# %%
import abjad
from surge.materials.segment_1.time_signatures import time_signatures
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-264d3e605fcd> in <module>()
#       1 import abjad
# ----> 2 from surge.materials.segment_1.time_signatures import time_signatures
#
# ~/dev/heave-sway-surge/surge/__init__.py in <module>()
#       1 # -*- coding: utf-8 -*-
#       2 import surge.build
# ----> 3 import surge.materials
#       4 import surge.segments
#       5 import surge.tools
#
# ~/dev/heave-sway-surge/surge/materials/__init__.py in <module>()
#       2
#       3 import surge.materials.segment_ii
# ----> 4 import surge.materials.segment_i
#       5 import surge.materials.woodwindfingerings
#       6
#
# ~/dev/heave-sway-surge/surge/materials/segment_i/__init__.py in <module>()
#       2 import surge.materials.segment_i.bass
#       3 import surge.materials.segment_i.cello
# ----> 4 import surge.materials.segment_i.clarinet
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4e0294c0febe> in <module>()
# ----> 1 from surge.materials.segment_1.time_signatures import time_signatures
#
# ~/dev/heave-sway-surge/surge/__init__.py in <module>()
#       1 # -*- coding: utf-8 -*-
#       2 import surge.build
# ----> 3 import surge.materials
#       4 import surge.segments
#       5 import surge.tools
#
# ~/dev/heave-sway-surge/surge/materials/__init__.py in <module>()
#       2
#       3 import surge.materials.segment_ii
# ----> 4 import surge.materials.segment_i
#       5 import surge.materials.woodwindfingerings
#       6
#
# ~/dev/heave-sway-surge/surge/materials/segment_i/__init__.py in <module>()
#       2 import surge.materials.segment_i.bass
#       3 import surge.materials.segment_i.cello
# ----> 4 import surge.materials.segment_i.clarinet
# ...
